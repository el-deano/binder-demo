# %%
# %run hello_world.py
# Out:
# Hello from binder

# %%
# !python hello_world.py
# Out:
# Hello from binder

# %%
import hello_world
# Out:
# Hello from binder

# %%
# %load hello_world.py
print("Hello from binder")
